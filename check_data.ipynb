# %%
import pandas as pd
import fund_variables as fv

# %%
df = pd.read_csv(fv.FUND_FILENAME, index_col=0)
df.sort_values(by="Percentage", ascending=False)
# Out:
#                                              Position    Value  Position_Size  \
# 1          Stockholm 2021 Challengers Sticker Capsule    14.90          436.0
# 4                 Sticker | rox (Holo) | Antwerp 2022   182.70           15.0
# 29                       Sticker | Liquid Fire (Holo)    61.00           40.0
# 0           Stockholm 2021 Contenders Sticker Capsule     5.70          419.0
# 3              Stockholm 2021 Legends Sticker Capsule     3.50          599.0
# 2           Antwerp 2022 Contenders Autograph Capsule     1.24         1105.0
# 5                 Sticker | max (Holo) | Antwerp 2022    23.86           49.0
# 16             Sticker | MOUZ (Holo) | Stockholm 2021    74.39           15.0
# 14         Sticker | Entropiq (Holo) | Stockholm 2021    14.20           65.0
# 46                    Sticker | Battle Scarred (Holo)    32.29           25.0
# 6                Sticker | ropz (Holo) | Antwerp 2022    29.09           27.0
# ...

# %%
sum(df.Position_purchase_price*df.Position_Size)
# Out:
# 35113.52

# %%
df = pd.read_csv('Data/Fund_Positions_TEST_2.csv', index_col=0)
df.sort_values(by="Percentage", ascending=False)
# Out:
#                                              Position    Value  Position_Size  \
# 1          Stockholm 2021 Challengers Sticker Capsule    15.17          255.0
# 4                 Sticker | rox (Holo) | Antwerp 2022   182.70           15.0
# 29                       Sticker | Liquid Fire (Holo)    61.00           40.0
# 0           Stockholm 2021 Contenders Sticker Capsule     5.79          419.0
# 3              Stockholm 2021 Legends Sticker Capsule     3.53          399.0
# 2           Antwerp 2022 Contenders Autograph Capsule     1.23         1105.0
# 5                 Sticker | max (Holo) | Antwerp 2022    23.86           49.0
# 14         Sticker | Entropiq (Holo) | Stockholm 2021    14.07           65.0
# 46                    Sticker | Battle Scarred (Holo)    32.19           25.0
# 19  Sticker | Copenhagen Flames (Holo) | Stockholm...    19.24           41.0
# 17      Sticker | paiN Gaming (Holo) | Stockholm 2021    18.90           38.0
# ...

# %%
df3 = pd.read_csv('planned_percentages.csv', index_col=0)
df3
